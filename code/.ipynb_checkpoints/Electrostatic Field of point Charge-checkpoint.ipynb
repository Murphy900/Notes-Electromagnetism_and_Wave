# %%
#Dieletric costant and unitary charge - - - - - -- - - -

DIEL = 8.854187822*10**(-12) 
Q =  1.6*10**(-19) #charge of a proton

# - - - -- - - - - - -- - - - - - - - - - - - - - - - -

q1 = Q
q2 = -3*Q


#Electrostatic field of a point charge 

def Ex (x,y,q,x0,y0):
    return q/(4.0*pi*DIEL)*(x-x0)/((x-x0)**2+(y-y0)**2)**(1.5)

def Ey (x,y,q,x0,y0):
    return q/(4*pi*DIEL)*(y-y0)/((x-x0)**2+(y-y0)**2)**(1.5)


# Total electrostatic field of two point charge at distance d on the x-axis 

Exx =  lambda x,y: Ex(x,y,q1,-3,0) + Ex(x,y,q2,3,0)
Eyy =  lambda x,y: Ey(x,y,q1,-3,0) + Ey(x,y,q2,3,0)

#plotting the normalized vector field (the problem with normalization is that we loss information about the strentgh of the field 

x,y = var('x y')
P = plot_vector_field((Exx(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2),Eyy(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2)),(x,-5,5), (y,-5,5))
C1 = point((-3,0),size = 150) + text('q',(-2.7,-0.5),fontsize = 20)
C2 = point((3,0),size = 150) + text('-3q',(3.2,0.5),fontsize = 20)
S = P+C1+C2
S.axes_labels([r'$E_x$',r'$E_y$'])
S.show(title = 'Electrostatic Field of a Point charge q ad -3q', fontsize = 15)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
q1 = Q
q2 = -Q
x,y = var('x y')
P = plot_vector_field((Exx(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2),Eyy(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2)),(x,-5,5), (y,-5,5))
D = density_plot((Exx(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2),Eyy(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2)),(x,-5,5), (y,-5,5), plot_points = 100)
C1 = point((-3,0),size = 150) + text('q',(-2.7,-0.5),fontsize = 20)
C2 = point((3,0),size = 150) + text('-q',(3.1,0.5),fontsize = 20)
S = P+C1+C2+D
S.axes_labels([r'$E_x$',r'$E_y$'])
S.show(title = 'Electrostatic Field of a Point charge q ad -q', fontsize = 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 x,y = var('x y')
#       4 P = plot_vector_field((Exx(x,y)/sqrt(Exx(x,y)**Integer(2)+Eyy(x,y)**Integer(2)),Eyy(x,y)/sqrt(Exx(x,y)**Integer(2)+Eyy(x,y)**Integer(2))),(x,-Integer(5),Integer(5)), (y,-Integer(5),Integer(5)))
# ----> 5 D = density_plot((Exx(x,y)/sqrt(Exx(x,y)**Integer(2)+Eyy(x,y)**Integer(2)),Eyy(x,y)/sqrt(Exx(x,y)**Integer(2)+Eyy(x,y)**Integer(2))),(x,-Integer(5),Integer(5)), (y,-Integer(5),Integer(5)))
#       6 C1 = point((-Integer(3),Integer(0)),size = Integer(150)) + text('q',(-RealNumber('2.7'),-RealNumber('0.5')),fontsize = Integer(20))
#       7 C2 = point((Integer(3),Integer(0)),size = Integer(150)) + text('-q',(RealNumber('3.1'),RealNumber('0.5')),fontsize = Integer(20))
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/decorators.py:497, in options.__call__.<locals>.wrapper(*args, **kwds)
#     495     options['__original_opts'] = kwds
#     496 options.update(kwds)
# --> 497 return func(*args, **options)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/plot/density_plot.py:308, in density_plot(f, xrange, yrange, **options)
#     306 from sage.plot.misc import setup_for_eval_on_grid
#     307 from sage.rings.real_double import RDF
# --> 308 g, ranges = setup_for_eval_on_grid([f], [xrange, yrange], options['plot_points'])
#     309 g = g[0]
#     310 xrange, yrange = (r[:2] for r in ranges)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/plot/misc.py:211, in setup_for_eval_on_grid(funcs, ranges, plot_points, return_vars, imaginary_tolerance)
#     209 # Handle vectors, lists, tuples, etc.
#     210 if isinstance(funcs, Iterable):
# --> 211     funcs = tuple( try_make_fast(f) for f in funcs )
#     212 else:
#     213     funcs = try_make_fast(funcs)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/plot/misc.py:211, in <genexpr>(.0)
#     209 # Handle vectors, lists, tuples, etc.
#     210 if isinstance(funcs, Iterable):
# --> 211     funcs = tuple( try_make_fast(f) for f in funcs )
#     212 else:
#     213     funcs = try_make_fast(funcs)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/plot/misc.py:203, in setup_for_eval_on_grid.<locals>.try_make_fast(f)
#     200 else:
#     201     # Convert things like ZZ(0) into constant functions.
#     202     from sage.symbolic.ring import SR
# --> 203     ff = fast_callable(SR(f),
#     204                        vars=vars,
#     205                        expect_one_var=eov,
#     206                        domain=CDF)
#     207     return FastCallablePlotWrapper(ff, imag_tol=imaginary_tolerance)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12676)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/coerce_maps.pyx:163, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6957)()
#     161             print(type(C), C)
#     162             print(type(C._element_constructor), C._element_constructor)
# --> 163         raise
#     164
#     165 cpdef Element _call_with_args(self, x, args=(), kwds={}) noexcept:
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/coerce_maps.pyx:158, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6849)()
#     156 cdef Parent C = self._codomain
#     157 try:
# --> 158     return C._element_constructor(x)
#     159 except Exception:
#     160     if print_warnings:
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/symbolic/ring.pyx:376, in sage.symbolic.ring.SymbolicRing._element_constructor_ (build/cythonized/sage/symbolic/ring.c:8453)()
#     374         TypeError: Malformed expression: λ + * !!!  1
#     375     """
# --> 376     return new_Expression(self, x)
#     377
#     378 def _force_pyobject(self, x, bint force=False, bint recursive=True):
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/symbolic/expression.pyx:13817, in sage.symbolic.expression.new_Expression (build/cythonized/sage/symbolic/expression.cpp:126262)()
#   13815         raise TypeError(f"unable to convert {x!r} to a symbolic expression")
#   13816 else:
# > 13817     raise TypeError(f"unable to convert {x!r} to a symbolic expression")
#   13818
#   13819 return new_Expression_from_GEx(parent, exp)
#
# TypeError: unable to convert (((4.51763626479800e-9)*(x + 3)/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*(x - 3)/(pi*((x - 3)^2 + y^2)^1.50000000000000))/sqrt(((4.51763626479800e-9)*(x + 3)/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*(x - 3)/(pi*((x - 3)^2 + y^2)^1.50000000000000))^2 + ((4.51763626479800e-9)*y/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*y/(pi*((x - 3)^2 + y^2)^1.50000000000000))^2), ((4.51763626479800e-9)*y/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*y/(pi*((x - 3)^2 + y^2)^1.50000000000000))/sqrt(((4.51763626479800e-9)*(x + 3)/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*(x - 3)/(pi*((x - 3)^2 + y^2)^1.50000000000000))^2 + ((4.51763626479800e-9)*y/(pi*((x + 3)^2 + y^2)^1.50000000000000) - (4.51763626479800e-9)*y/(pi*((x - 3)^2 + y^2)^1.50000000000000))^2)) to a symbolic expression

# %%
q1 = Q
q2 = -3*Q
x,y = var('x y')
P = streamline_plot((Exx(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2),Eyy(x,y)/sqrt(Exx(x,y)**2+Eyy(x,y)**2)),(x,-5,5), (y,-5,5))
C1 = point((-3,0),size = 150) + text('q',(-2.7,-0.5),fontsize = 20)
C2 = point((3,0),size = 150) + text('-3q',(3.1,0.5),fontsize = 20)
S = P+C1+C2
S.axes_labels([r'$E_x$',r'$E_y$'])
S.show(title = 'Electrostatic Field of a Point charge q ad -3q', fontsize = 15)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
x,y = var('x y')
P = plot_vector_field((Ex(x,y,q1,0,0),Ey(x,y,q1,0,0)),(x,-5,5), (y,-5,5))
C1 = point((0,0),size = 150) + text('q',(-0.3,-0.5),fontsize = 20)
S = P+C1
S.axes_labels([r'$E_x$',r'$E_y$'])
S.show(title = 'Electrostatic Field of a Point charge +q ', fontsize = 15)
# Out:
# Graphics object consisting of 3 graphics primitives
